# %%
from pinecone import Pinecone
from sentence_transformers import SentenceTransformer
import os
pc = Pinecone(
        api_key=os.getenv('PINECONE_API_KEY')
    )
index=pc.Index('medrag')

# %%
model = SentenceTransformer("pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb")

# %%
query='irregular periods and acne'
embeddings = model.encode([query], batch_size=32, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
result = index.query(
    vector=embeddings[0].tolist(),
    top_k=5,
    include_metadata=True  # so you get back associated text/snippet/url/etc.
)

# %%
result
# Out:
# {'matches': [{'id': 'chunk-42963',
#               'metadata': {'chunk_index': 46.0,
#                            'duration': 165.28199999999998,
#                            'start_time': 3300.319,
#                            'text': ' a unilateral recurrent headache episodes '
#                                    'of one and a half hours in an adult man so '
#                                    'in terms of primary headaches we were '
#                                    'thinking about uh trigeminal autonomic '
#                                    'synthalgias and there are different types '
#                                    'of disc category some clues that can help '
#                                    'us to differentiate the types of these '
#                                    'exceptions are the attack duration and the '
#                                    'frequency attacks so in terms of the '
#                                    'attack duration in crescendo order we have '
#                                    'the sun the tsuna paroxysmal micronia the '
#                                    'cluster and immigrant continuum so for the '
#                                    'paraxismalimikrania typically lasts less '
#                                    'than 30 minutes and the plaster typically '
#                                    'lasts less than um 180 minutes so we were '
#                                    'thinking um in this could be apparent '
#                                    'malaymicrania cluster or a microcontinent '
#                                    'and in terms of the also we were thinking '
#                                    'uh we have to inquire about medication '
#                                    'compliance because headaches the episodes '
#                                    'of hades can a worsen due to a medication '
#                                    'overuse or medication of compliance um in '
#                                    'terms of the secondary headaches um we '
#                                    'have a red flag that was uh the worsening '
#                                    'of headaches as itself so the presence of '
#                                    'a red class requires workup so if imaging '
#                                    'could be needed but this is not uh as '
#                                    'black and white as we can',
#                            'url': 'https://www.youtube.com/watch?v=H_maGfOKlD4\n'},
#               'score': 0.498186976,
#               'values': []},
#              {'id': 'chunk-1741',
#               'metadata': {'chunk_index': 10.0,
#                            'duration': 149.2,
#                            'start_time': 737.519,
#                            'text': ' so just to sort of highlight right we had '
#                                    'this initial disease syndrome that was '
#                                    'characterized primarily by um features '
#                                    'suggestive of elevated androgenic hormones '
#                                    'right that being things like the facial '
#                                    'hair development or hirsutism as well as '
#                                    "the acne and then we're seeing not only in "
#                                    'this aliquot more and more signs of '
#                                    'elevated androgenic hormones but also some '
#                                    "other abnormalities that don't necessarily "
#                                    'map on perfectly to our illness script for '
#                                    'elevated androgens in and of themselves '
#                                    'and those features particularly are things '
#                                    'like the presence of hypertension as well '
#                                    'as the presence of hypokalemia right so '
#                                    'androgen sex hormones in and of themselves '
#                                    "don't necessarily mediate our serum "
#                                    'potassium levels things like testosterone '
#                                    'dhea the things that mediate our serum '
#                                    'potassium levels are primarily going to be '
#                                    'things like aldosterone for example and so '
#                                    "if we're now asking ourselves are there "
#                                    'other coexisting endocrine abnormalities '
#                                    'that could be mediating some of some of '
#                                    'these findings we have to ask ourselves '
#                                    'what are the elements of the hormonal '
#                                    'access which is where our center of '
#                                    'gravity is focusing right now given the '
#                                    'presenting features what are the elements '
#                                    'of the hormonal access that can mediate '
#                                    'things like blood pressure as well as '
#                                    'potassium',
#                            'url': 'https://www.youtube.com/watch?v=RsIjAEwrk38\n'},
#               'score': 0.479836851,
#               'values': []},
#              {'id': 'chunk-33499',
#               'metadata': {'chunk_index': 20.0,
#                            'duration': 138.79899999999998,
#                            'start_time': 1780.2,
#                            'text': ' started with the chief complaint of '
#                                    'itching which is kind of the most General '
#                                    'Chief complaint of all time and the the '
#                                    'way we decided to break it down is is it a '
#                                    "rash that's itchy or is it an itch that "
#                                    'rashes and in particular we talked about '
#                                    'using the physical exam to discover if '
#                                    'there are parts of the rash that are '
#                                    'present in places the patient cannot reach '
#                                    "and that will help you decide whether it's "
#                                    'a a rash that ages or an H that rashes '
#                                    'after the biopsy findings though this case '
#                                    'got a lot more interesting perigo '
#                                    "nodularis is something that I've learned "
#                                    'about today for the first time these firm '
#                                    'dome-shaped nodules that are '
#                                    'non-hereditary non-contagious with an '
#                                    'unclear pathogenesis but with a variety of '
#                                    "ideologies which we'll talk about that "
#                                    'arise as a result of scratching for '
#                                    "prolonged period of time they're closely "
#                                    'associated with atopic conditions such as '
#                                    'atopic dermatitis and other inflammatory '
#                                    'conditions infections and notably cancer '
#                                    'which in this case was the cause as well '
#                                    'as other non-inflammatory conditions such '
#                                    'as diabetes liver and kidney disease that '
#                                    'were ruled out by previous providers we '
#                                    'moved on to a discussion of cancers',
#                            'url': 'https://www.youtube.com/watch?v=9AJ2VTmIeLA\n'},
#               'score': 0.469425052,
#               'values': []},
#              {'id': 'chunk-39074',
#               'metadata': {'chunk_index': 23.0,
#                            'duration': 154.48,
#                            'start_time': 1602.159,
#                            'text': ' think of a periodic rash we should think '
#                                    'about dry skin scabies medication side '
#                                    'effects urethricaria atopic dermatitis and '
#                                    'also thematics have put hepatitis during '
#                                    'can also cause that um that that is seen '
#                                    'with celiac disease whenever we think '
#                                    'about purple orbits type one thinking and '
#                                    'makes us think about um the hedotrope rash '
#                                    'seen in their modern myositis and it '
#                                    'typically spares the nasolabial folds no '
#                                    "that's wrong it does affect the nasolabial "
#                                    'folds in lupus it bears the nasolabial '
#                                    "folds and that's sorry for my ending i'm "
#                                    'wrong for my ending then we can also see '
#                                    'gotron papules mechanic hands the shawl '
#                                    'titus can affect the skin the muscle the '
#                                    'line with ild and also the vasculature for '
#                                    "example with raynaud's or pulmonary "
#                                    "hypertension there's a right i also want "
#                                    'to share random pearl on how to '
#                                    'differentiate mechanic hands seen in them '
#                                    'out of my sight is from the mat from '
#                                    'mahantic hands from people that really '
#                                    'work with their hands usually when you '
#                                    'have trauma to your hands it happens to '
#                                    'the tips and when it happens when you have '
#                                    'ulcers and nauseas on the lateral sides of '
#                                    'your fingers this points more to a sign of '
#                                    'thematomyositis',
#                            'url': 'https://www.youtube.com/watch?v=hVldqFm5U1A\n'},
#               'score': 0.452422321,
#               'values': []},
#              {'id': 'chunk-10244',
#               'metadata': {'chunk_index': 6.0,
#                            'duration': 152.921,
#                            'start_time': 455.479,
#                            'text': ' think first characterizing is it like '
#                                    'diffuse thinning is it just on the scalp '
#                                    'or is it a specific location and then just '
#                                    'applying the base rate and saying hey '
#                                    'testosterone in men and women is going to '
#                                    'be the primary cause of hair loss and then '
#                                    'thinking of those conditions in women '
#                                    'specifically polycystic ovarian uh '
#                                    'syndrome now with constipation '
#                                    'constipation is not uncommon and we all '
#                                    'have experienced it uh in one form or '
#                                    'another the question is when should we get '
#                                    'concerned like when should there be a '
#                                    'reason for us to actually dive into '
#                                    'constipation I would say and I learned '
#                                    'this from Robbie and he has a terrific '
#                                    'figure that I encourage you guys to go '
#                                    'look up on clinical problem solvers if '
#                                    "that constipation is the sudden onset it's "
#                                    "brand new if it's refractory to treatment "
#                                    "if it's associated with any other red "
#                                    'flags then you should be concerned for '
#                                    'example weakness urinary any other '
#                                    'neurologic symptoms since this has seems '
#                                    "like it's a new con a new concern and "
#                                    "there's all these other Associated "
#                                    "symptoms it's worth thinking about "
#                                    "secondary causes of constipation and it's "
#                                    'so easy to see how that constipation may '
#                                    'not even be',
#                            'url': 'https://www.youtube.com/watch?v=SavHKY4vQRI\n'},
#               'score': 0.450488389,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}
